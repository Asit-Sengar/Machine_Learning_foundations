# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../datasets/placement.csv")
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'cgpa', 'iq', 'placement'], dtype='object')

# %%
print(df["cgpa"])
# Out:
# 0     6.8
# 1     5.9
# 2     5.3
# 3     7.4
# 4     5.8
#      ...
# 95    4.3
# 96    4.4
# 97    6.7
# 98    6.3
# 99    6.2
# Name: cgpa, Length: 100, dtype: float64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB
# None

# %%
plt.plot(df["cgpa"],df["iq"])

# %%
plt.scatter(df["cgpa"],df["iq"],c = df["placement"])

# %%
x = df.iloc[:,0:2]#this is independent variable
y = df.iloc[:,-1]#this is dependent variable
y = y.astype("int8")#changing the data type so that it covers less memory

# %%
print(x)
# Out:
#     Unnamed: 0  cgpa
# 0            0   6.8
# 1            1   5.9
# 2            2   5.3
# 3            3   7.4
# 4            4   5.8
# ..         ...   ...
# 95          95   4.3
# 96          96   4.4
# 97          97   6.7
# 98          98   6.3
# 99          99   6.2
#
# [100 rows x 2 columns]

# %%
print(y)
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.1)

# %%
x_train
# Out:
#     Unnamed: 0  cgpa
# 64          64   7.0
# 26          26   7.0
# 42          42   7.6
# 85          85   5.8
# 35          35   6.8
# ..         ...   ...
# 82          82   6.5
# 45          45   6.0
# 14          14   6.1
# 77          77   7.3
# 72          72   7.3
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 64    1
# 26    1
# 42    1
# 85    1
# 35    1
#      ..
# 82    1
# 45    1
# 14    0
# 77    1
# 72    1
# Name: placement, Length: 90, dtype: int8

# %%
x_test
# Out:
#     Unnamed: 0  cgpa
# 5            5   7.1
# 80          80   4.9
# 11          11   6.9
# 10          10   6.0
# 12          12   5.4
# 20          20   6.6
# 29          29   7.0
# 19          19   5.2
# 43          43   6.8
# 56          56   6.1

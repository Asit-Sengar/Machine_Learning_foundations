# %% [markdown]
# overfitting means that the value of m in linear regression is very high

# %% [markdown]
# underfitting means that the value of b in linear regression is very high

# %% [markdown]
# we are trying to regularise the data, it means increasing the bias and decreasing the variance
# signifincantly

# %% [markdown]
# this is also known as bias variance tradeoff

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_diabetes

# %%
data = load_diabetes()

# %%
print(type(data))#as we can see it is a bunch object
# Out:
# <class 'sklearn.utils._bunch.Bunch'>

# %%
X= data.data
Y = data.target

# %%
X_train ,

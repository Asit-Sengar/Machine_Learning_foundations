# %%
import numpy as np
import pandas as pd

# %%
dataframe = pd.read_csv("../../datasets/menstrual_cycle_dataset_with_factors(1).csv")

# %%
dataframe.sample(5)
# Out:
#      User ID  Age    BMI  Stress Level Exercise Frequency  Sleep Hours  \
# 107       12   29  29.49             4               High          5.5
# 408       46   25  23.71             4           Moderate          5.3
# 154       17   41  23.92             5               High          7.8
# 17         2   34  29.57             4                Low          5.4
# 844       94   20  21.13             4           Moderate          6.9
#
#            Diet Cycle Start Date  Cycle Length  Period Length  \
# 107  High Sugar          52:34.9            31              4
# 408  High Sugar          52:34.9            33              5
# 154  High Sugar          52:34.9            37              7
# 17     Low Carb          52:34.9            34              4
# 844    Low Carb          52:34.9            31              5
#
#     Next Cycle Start Date     Symptoms
# 107               52:34.9       Cramps
# 408               52:34.9      Fatigue
# 154               52:34.9      Fatigue
# ...

# %%
dataframe.columns
# Out:
# Index(['User ID', 'Age', 'BMI', 'Stress Level', 'Exercise Frequency',
#        'Sleep Hours', 'Diet', 'Cycle Start Date', 'Cycle Length',
#        'Period Length', 'Next Cycle Start Date', 'Symptoms'],
#       dtype='object')

# %%
dataframe.dtypes
# Out:
# User ID                    int64
# Age                        int64
# BMI                      float64
# Stress Level               int64
# Exercise Frequency        object
# Sleep Hours              float64
# Diet                      object
# Cycle Start Date          object
# Cycle Length               int64
# Period Length              int64
# Next Cycle Start Date     object
# Symptoms                  object
# dtype: object

# %%
#changing the datatype of date column
dataframe["Cycle Start Date"] = pd.to_datetime(dataframe["Cycle Start Date"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/parsing.pyx:684, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 #changing the datatype of date column
# ----> 2 dataframe["Cycle Start Date"] = pd.to_datetime(dataframe["Cycle Start Date"])
#
# File c:\Users\asits\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.tz_localize("utc")
#    1067 elif isinstance(arg, ABCSeries):
# -> 1068     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %% [markdown]
# Import core libraries for numerical work and data handling.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Load the Titanic training dataset and preview the first rows.

# %%
df = pd.read_csv("../../datasets/train.csv")
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Split features and target into training and testing datasets.

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(df.drop(columns = ["Survived"]),df["Survived"], test_size = 0.3)

# %% [markdown]
# Inspect a random sample from the training features.

# %%
X_train.sample(5)
# Out:
#      PassengerId  Pclass                            Name     Sex   Age  SibSp  \
# 455          456       3              Jalsevac, Mr. Ivan    male  29.0      0
# 537          538       1             LeRoy, Miss. Bertha  female  30.0      0
# 210          211       3                  Ali, Mr. Ahmed    male  24.0      0
# 321          322       3                Danoff, Mr. Yoto    male  27.0      0
# 367          368       3  Moussa, Mrs. (Mantoura Boulos)  female   NaN      0
#
#      Parch              Ticket      Fare Cabin Embarked
# 455      0              349240    7.8958   NaN        C
# 537      0            PC 17761  106.4250   NaN        C
# 210      0  SOTON/O.Q. 3101311    7.0500   NaN        S
# 321      0              349219    7.8958   NaN        S
# 367      0                2626    7.2292   NaN        C

# %% [markdown]
# Note which categorical encoding strategy fits ordered and unordered columns.

# %%
#if there is a order then i will do ordinal encoding 
#if there isnt any order then i will do one hot encoding

# %% [markdown]
# Create a ColumnTransformer object for preprocessing selected columns.

# %% [markdown]
# Check missing value counts in each dataset column.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
